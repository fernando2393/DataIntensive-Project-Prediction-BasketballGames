// %%
import org.apache.spark.sql.{DataFrame, Dataset, Row, SparkSession}
import org.apache.spark.sql.functions._
val spark = SparkSession.builder.master("local[*]").appName("dataProcessing").getOrCreate()
import spark.implicits._
// Out:
// spark = org.apache.spark.sql.SparkSession@279d755d
// org.apache.spark.sql.SparkSession@279d755d
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// class org.apache.spark.sql.catalyst.expressions.GenericRowWithSchema
// int
// ...

// %%
var df_stats = spark.read.json("data/stats_data.json")
df_stats.printSchema()
// Out:
// root
//  |-- data: array (nullable = true)
//  |    |-- element: struct (containsNull = true)
//  |    |    |-- ast: long (nullable = true)
//  |    |    |-- blk: long (nullable = true)
//  |    |    |-- dreb: long (nullable = true)
//  |    |    |-- fg3_pct: double (nullable = true)
//  |    |    |-- fg3a: long (nullable = true)
//  |    |    |-- fg3m: long (nullable = true)
//  |    |    |-- fg_pct: double (nullable = true)
//  |    |    |-- fga: long (nullable = true)
//  |    |    |-- fgm: long (nullable = true)
//  |    |    |-- ft_pct: double (nullable = true)
//  |    |    |-- fta: long (nullable = true)
//  |    |    |-- ftm: long (nullable = true)
//  |    |    |-- game: struct (nullable = true)
//  |    |    |    |-- date: string (nullable = true)
//  |    |    |    |-- home_team_id: long (nullable = true)
//  |    |    |    |-- home_team_score: long (nullable = true)
//  |    |    |    |-- id: long (nullable = true)
//  |    |    |    |-- period: long (nullable = true)
// ...

// %%
val df = spark.read.json("data/players_data.json")
//Read the players JSON file
df.show()
df.printSchema()
// Out:
// +--------------------+--------------------+
// |                data|                meta|
// +--------------------+--------------------+
// |[[Ike,,, 14, Anig...|[1, 2, 100, 3268,...|
// |[[Ike,,, 14, Anig...|[1, 2, 100, 3268,...|
// |[[Danny,,, 571, Y...|[2, 3, 100, 3268,...|
// |[[Larry,,, 671, J...|[3, 4, 100, 3268,...|
// |[[Alonzo,,, 771, ...|[4, 5, 100, 3268,...|
// |[[Skeeter,,, 871,...|[5, 6, 100, 3268,...|
// |[[Kevin,,, 971, G...|[6, 7, 100, 3268,...|
// |[[Jason,,, 1071, ...|[7, 8, 100, 3268,...|
// |[[Randell,,, 1171...|[8, 9, 100, 3268,...|
// |[[Derrick,,, 1271...|[9, 10, 100, 3268...|
// |[[Jason,,, 1372, ...|[10, 11, 100, 326...|
// |[[Luke,,, 1472, W...|[11, 12, 100, 326...|
// |[[Justin,,, 1572,...|[12, 13, 100, 326...|
// |[[Robert,,, 1673,...|[13, 14, 100, 326...|
// |[[Spencer,,, 1775...|[14, 15, 100, 326...|
// |[[Derrick,,, 1875...|[15, 16, 100, 326...|
// |[[Diamon,,, 1977,...|[16, 17, 100, 326...|
// |[[Cory,,, 2083, J...|[17, 18, 100, 326...|
// ...

// %%
var elem = df.select(explode($"data").as("data_flat"))
elem.show()
// Out:
// +--------------------+
// |           data_flat|
// +--------------------+
// |[Ike,,, 14, Anigb...|
// |[Ron,,, 25, Baker...|
// |[Jabari,,, 47, Bi...|
// |[MarShon,,, 67, B...|
// |[Lorenzo,,, 71, B...|
// |[Omri,,, 90, Cass...|
// |[Alex, 6, 6, 1, A...|
// |[Tyler,,, 119, Da...|
// |[Keenan,,, 149, E...|
// |[Marcin,,, 179, G...|
// |[Andrew,,, 1593, ...|
// |[Amir, 6, 9, 241,...|
// |[George, 6, 6, 25...|
// |[Zach,,, 281, Lof...|
// |[Kosta, 7, 0, 263...|
// |[James,,, 348, Nu...|
// |[Billy,,, 382, Pr...|
// |[Zhou,,, 384, Qi,...|
// |[Zach,,, 388, Ran...|
// |[Malachi,,, 392, ...|
// +--------------------+
// only showing top 20 rows
// elem = [data_flat: struct<first_name: string, height_feet: bigint ... 6 more fields>]
// [data_flat: struct<first_name: string, height_feet: bigint ... 6 more fields>]

// %%
// Flattening

var elem = df.select(explode($"data").as("data_flat"))
elem.show()
val players_id = elem.select("data_flat.id")
players_id.show()
// Out:
// +--------------------+
// |           data_flat|
// +--------------------+
// |[Ike,,, 14, Anigb...|
// |[Ron,,, 25, Baker...|
// |[Jabari,,, 47, Bi...|
// |[MarShon,,, 67, B...|
// |[Lorenzo,,, 71, B...|
// |[Omri,,, 90, Cass...|
// |[Alex, 6, 6, 1, A...|
// |[Tyler,,, 119, Da...|
// |[Keenan,,, 149, E...|
// |[Marcin,,, 179, G...|
// |[Andrew,,, 1593, ...|
// |[Amir, 6, 9, 241,...|
// |[George, 6, 6, 25...|
// |[Zach,,, 281, Lof...|
// |[Kosta, 7, 0, 263...|
// |[James,,, 348, Nu...|
// |[Billy,,, 382, Pr...|
// |[Zhou,,, 384, Qi,...|
// |[Zach,,, 388, Ran...|
// |[Malachi,,, 392, ...|
// +--------------------+
// only showing top 20 rows
//
// +----+
// |  id|
// +----+
// |  14|
// |  25|
// |  47|
// |  67|
// |  71|
// |  90|
// |   1|
// | 119|
// | 149|
// | 179|
// |1593|
// | 241|
// | 256|
// | 281|
// | 263|
// | 348|
// | 382|
// | 384|
// | 388|
// | 392|
// +----+
// only showing top 20 rows
// ...

// %%
elem.select(elem("data_flat.first_name"), elem("data_flat.last_name")).filter(elem("data_flat.id")===237).show()
// Out:
// +----------+---------+
// |first_name|last_name|
// +----------+---------+
// |    LeBron|    James|
// +----------+---------+

// %%
var flat_stats = df_stats.select(explode($"data").as("flat_stats"))
val stats_season = flat_stats.select("flat_stats.game.season")
val stats_player_id = flat_stats.select("flat_stats.player.id")
stats_player_id.show()
// Out:
// +---+
// | id|
// +---+
// |415|
// | 49|
// | 91|
// |210|
// |161|
// | 53|
// |157|
// | 24|
// |235|
// |174|
// |299|
// |309|
// |263|
// | 33|
// |482|
// | 48|
// |267|
// |465|
// |207|
// | 62|
// +---+
// only showing top 20 rows
// flat_stats = [flat_stats: struct<ast: bigint, blk: bigint ... 21 more fields>]
// stats_season = [season: bigint]
// stats_player_id = [id: bigint]
// [id: bigint]

// %%
flat_stats.printSchema()
// Out:
// root
//  |-- flat_stats: struct (nullable = true)
//  |    |-- ast: long (nullable = true)
//  |    |-- blk: long (nullable = true)
//  |    |-- dreb: long (nullable = true)
//  |    |-- fg3_pct: double (nullable = true)
//  |    |-- fg3a: long (nullable = true)
//  |    |-- fg3m: long (nullable = true)
//  |    |-- fg_pct: double (nullable = true)
//  |    |-- fga: long (nullable = true)
//  |    |-- fgm: long (nullable = true)
//  |    |-- ft_pct: double (nullable = true)
//  |    |-- fta: long (nullable = true)
//  |    |-- ftm: long (nullable = true)
//  |    |-- game: struct (nullable = true)
//  |    |    |-- date: string (nullable = true)
//  |    |    |-- home_team_id: long (nullable = true)
//  |    |    |-- home_team_score: long (nullable = true)
//  |    |    |-- id: long (nullable = true)
//  |    |    |-- period: long (nullable = true)
//  |    |    |-- postseason: boolean (nullable = true)
//  |    |    |-- season: long (nullable = true)
// ...

// %%
// val player_games = flat_stats.select($"flat_stats.team.id").filter($"flat_stats.player.id" === 237 && $"flat_stats.game.season" === 2018)
// val rows = player_games.rdd
// val player_teams = rows.map(x => (x, 1))
// val player_teams_reduced = player_teams.reduceByKey(_ + _).takeOrdered(1)(Ordering[Int].reverse.on(_._2))
// player_teams_reduced.foreach(println)
// Out:
// Syntax Error.:

// %%
def loopingFunction(row):
    return (row.id)
// Out:
// Compile Error: <console>:1: error: ':' expected but ')' found.
// def loopingFunction(row):
//                        ^

// %%
var season = Array(200, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012)
for(x <- season) {
    val player_distinct = flat_stats.select("flat_stats.player.id").filter($"flat_stats.game.season" === x).distinct()
    for(y <- player_distinct){
        val player_games = flat_stats.select($"flat_stats.team.id").filter($"flat_stats.player.id" === 237 && $"flat_stats.game.season" === x)
        //println(y)
         val rows = player_games.rdd
         val player_teams = rows.map(x => (x, 1))
         val player_teams_reduced = player_teams.reduceByKey(_ + _).takeOrdered(1)(Ordering[Int].reverse.on(_._2))
         player_teams_reduced.foreach(println)
         println("asdf")
    }

    
    
}
//     players = distinct(flat_stats.player.id, season == season)
//     for players
// Out:
// Unknown Error: <console>:40: error: value id is not a member of org.apache.spark.sql.Row
//            val player_distinct = flat_stats.select("flat_stats.player.id").filter($"flat_stats.game.season" === x).distinct().rdd.map(x => x.id)
//                                                                                                                                              ^

// %%
val player_distinct = flat_stats.select("flat_stats.player.id").filter($"flat_stats.game.season" === 2018).distinct().take(5)
player_distinct.getClass
println(player_distinct.count)
// Out:
// 536
// player_distinct = MapPartitionsRDD[48] at rdd at <console>:36
// MapPartitionsRDD[48] at rdd at <console>:36

// %%
var test = df_player.select(df_player("data.first_name")).filter(df_player.id === 4)
test.show()

//val pollingDF = df.select(df("precinct_name"), precinctColumn, votesColumn).filter(precinctColumn.isNotNull)
// Out:
// Unknown Error: lastException: Throwable = null
// <console>:34: error: not found: value df_player
//        var test = df_player.select(df_player("data.first_name")).filter(df_player.id === 4)
//                   ^
// <console>:34: error: not found: value df_player
//        var test = df_player.select(df_player("data.first_name")).filter(df_player.id === 4)
//                                    ^
// <console>:34: error: not found: value df_player
//        var test = df_player.select(df_player("data.first_name")).filter(df_player.id === 4)
//                                                                         ^

// %%
val player_games = df_stats.filter($"df_stats.player.id" === 4 && $"df_stats.game.season" === 2017)
// Out:
// org.apache.spark.sql.AnalysisException: cannot resolve '`df_stats.player.id`' given input columns: [data, meta];;
// 'Filter (('df_stats.player.id = 4) && ('df_stats.game.season = 2017))
// +- Relation[data#6,meta#7] json
//   at org.apache.spark.sql.catalyst.analysis.package$AnalysisErrorAt.failAnalysis(package.scala:42)
//   at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1$$anonfun$apply$3.applyOrElse(CheckAnalysis.scala:110)
//   at org.apache.spark.sql.catalyst.analysis.CheckAnalysis$$anonfun$checkAnalysis$1$$anonfun$apply$3.applyOrElse(CheckAnalysis.scala:107)
//   at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$transformUp$1.apply(TreeNode.scala:278)
//   at org.apache.spark.sql.catalyst.trees.TreeNode$$anonfun$transformUp$1.apply(TreeNode.scala:278)
//   at org.apache.spark.sql.catalyst.trees.CurrentOrigin$.withOrigin(TreeNode.scala:70)
//   at org.apache.spark.sql.catalyst.trees.TreeNode.transformUp(TreeNode.scala:277)
// ...
